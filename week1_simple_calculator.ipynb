# %%
# %%markdown
# # **Week_1_Simple_calculator**
# *This notebook takes two number and perform addition,subtraction,multiplication and division*
# Out:
# # **Week_1_Simple_calculator**
# *This notebook takes two number and perform addition,subtraction,multiplication and division*

# %%
print("=====SIMPLE CALCULATOR=====")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
# Out:
# =====SIMPLE CALCULATOR=====
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division

# %%
num1= float(input(("Enter your first number")))
num2= float(input(("Enter your second number")))

# %%
add=num1+num2
sub=num1-num2
Mult=num1*num2
div=num1/num2
print("\n====Results====")
print("Addition:",add)
print("Subtraction:",sub)
print("Multipication:",Mult)
print("Division:",div)
# Out:
# ====Results====
# Addition: 15475.0
# Subtraction: 299.0
# Multipication: 59846556.0
# Division: 1.0394043226146548
