# %%
# %%markdown
# # Week 2 project
# ## _Temperature Converter_
# Out:
# # Week 2 project
# ## _Temperature Converter_

# %%
# %%markdown
# ##*Formulas*
# Fahrenheit = (celsius *9/5) + 32
# celsius = (fahrenheit - 32) * 5/9
# Out:
# ##*Formulas*
# Fahrenheit = (celsius *9/5) + 32/n
# celsius = (fahrenheit - 32) * 5/9

# %%
#Celsius to Fahrenheit conversion
celsius = float(input(("Enter temprature in celsius: ")))
fahrenheit = (celsius *9/5) + 32
print("Temprature in fahrenheit:", fahrenheit)
#
# Out:
# Enter temprature in celsius: 25
# Temprature in fahrenheit: 77.0

# %%
#Fahrenhit to celsius conversion
fahrenheit = float(input(("Enter fahrenheit value for conversion: ")))
celsius = (fahrenheit - 32) * 5/9
print("Temprature in celsius:", celsius)
# Out:
# Enter fahrenheit value for conversion: 77
# Temprature in celsius: 25.0
